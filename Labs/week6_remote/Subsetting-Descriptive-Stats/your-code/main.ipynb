# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in this lab's data folder.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here
import pandas as pd
import seaborn as sns
# Out:
# C:\Users\pedro\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here
temp = pd.read_csv('../data/Temp_States.csv', sep=';')

# %% [markdown]
# #### Print `temp`.

# %%
temp.drop(columns=['Unnamed: 3'], inplace=True)

# %%
# your code here
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %%
"""
your comments here
"""

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here
temp.query('State == "New York"')
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here
temp.query('State == "New York"')['Temperature'].mean()
# Out:
# 10.740740739000001

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here
temp.query('Temperature > 15')[['City','State']]
# Out:
#        City        State
# 0       NYC     New York
# 3  Hartford  Connecticut
# 5    Treton   New Jersey
# 6    Newark   New Jersey

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here
temp.query('Temperature > 15')['City']
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here
temp.query('15 < Temperature < 20')['City']
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
# your code here
temp.groupby('State').mean().reset_index
# Out:
# <bound method DataFrame.reset_index of              Temperature
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741>

# %% [markdown]
# # [ONLY ONE MANDATORY]  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here
employess= pd.read_csv('../data/employees.csv',sep=';')
employess.drop(columns=['Unnamed: 7'], inplace=True)

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here
employess.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %%
"""
your comments here
"""

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here
employess['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here
employess['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here
employess['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here
employess.query('Salary == 30')
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here
employess.query('Name == "David"')
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here
employess.query('Name == "David"')['Salary'].values[0]
# Out:
# 30

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here
employess.query('Title == "associate"')
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here
employess.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# Method 2
# your code here
employess.iloc[0:3,:]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here
employess.query('Salary > 55')
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here
employess.groupby('Years').mean().reset_index()
# Out:
#    Years     Salary
# 0      1  35.000000
# 1      2  38.333333
# 2      3  55.000000
# 3      4  35.000000
# 4      7  60.000000
# 5      8  70.000000

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here
employess.groupby('Title').mean().reset_index()
# Out:
#        Title  Years     Salary
# 0         VP   8.00  70.000000
# 1    analyst   2.25  32.500000
# 2  associate   4.00  56.666667

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here
employess['Salary'].describe()
# Out:
# count     9.000000
# mean     48.888889
# std      16.541194
# min      30.000000
# 25%      35.000000
# 50%      55.000000
# 75%      60.000000
# max      70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
# your code here
employess.groupby(by='Gender')['Salary'].mean()
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here
employess.groupby(by='Department').describe().T
# Out:
# Department           HR         IT      Sales
# Years  count   3.000000   4.000000   2.000000
#        mean    4.666667   4.500000   2.500000
#        std     3.055050   3.511885   0.707107
#        min     2.000000   1.000000   2.000000
#        25%     3.000000   1.750000   2.250000
#        50%     4.000000   4.500000   2.500000
#        75%     6.000000   7.250000   2.750000
#        max     8.000000   8.000000   3.000000
# Salary count   3.000000   4.000000   2.000000
#        mean   45.000000  48.750000  55.000000
#        std    21.794495  19.311050   0.000000
#        min    30.000000  30.000000  55.000000
#        25%    32.500000  33.750000  55.000000
#        50%    35.000000  47.500000  55.000000
#        75%    52.500000  62.500000  55.000000
#        max    70.000000  70.000000  55.000000

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here
employess.groupby(['Department'])['Salary'].apply(lambda x : x.max() - x.min())
# Out:
# Department
# HR       40
# IT       40
# Sales     0
# Name: Salary, dtype: int64

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here
orders = pd.read_csv('../data/Orders.csv')

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  object
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  object
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  object
#  10  UnitPrice     397924 non-null  float64
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  object
#  13  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB

# %%
"""
your comments here
"""
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here
orders['amount_spent'].mean()
# Out:
# 22.39474850474768

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here
orders['amount_spent'].max()
# Out:
# 168469.6

# %%
orders['amount_spent'].min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here
customers_spain = orders[(orders['Country'] == 'Spain')].groupby(['CustomerID'])[['amount_spent', 'UnitPrice']].mean()

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here
customers_spain.shape
# Out:
# (30, 2)

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here
customers_quantity = orders[(orders['Quantity'] > 50)].groupby(['CustomerID'])[['Quantity']]
customers_quantity.describe()
# Out:
#            Quantity                                                       \
#               count          mean         std      min      25%      50%
# CustomerID
# 12346           1.0  74215.000000         NaN  74215.0  74215.0  74215.0
# 12347           1.0    240.000000         NaN    240.0    240.0    240.0
# 12348          19.0    110.315789   29.763984     72.0     76.0    120.0
# 12355           2.0     78.000000   25.455844     60.0     69.0     78.0
# 12356           5.0     88.800000   28.899827     60.0     72.0     72.0
# ...             ...           ...         ...      ...      ...      ...
# 18246           2.0     70.000000   14.142136     60.0     65.0     70.0
# 18248           1.0     72.000000         NaN     72.0     72.0     72.0
# 18251          16.0    489.000000  158.926398     72.0    432.0    528.0
# 18260           1.0     96.000000         NaN     96.0     96.0     96.0
# 18287           1.0     60.000000         NaN     60.0     60.0     60.0
#
#
# ...

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here
customers_quantity = orders[(orders['Quantity'] > 50) & (orders['Country'] == 'Spain')].groupby(['CustomerID'])[['Quantity']]

customers_quantity.describe()
# Out:
#            Quantity
#               count        mean         std    min    25%    50%    75%    max
# CustomerID
# 12454           4.0  158.000000  105.603030   72.0   72.0  136.0  222.0  288.0
# 12484           1.0   60.000000         NaN   60.0   60.0   60.0   60.0   60.0
# 12507           5.0  131.200000    7.155418  128.0  128.0  128.0  128.0  144.0
# 12546           1.0   96.000000         NaN   96.0   96.0   96.0   96.0   96.0
# 12557          24.0  168.416667  111.925409   60.0   93.0  122.0  222.0  360.0
# 12596           1.0   96.000000         NaN   96.0   96.0   96.0   96.0   96.0
# 12597           3.0   72.000000    0.000000   72.0   72.0   72.0   72.0   72.0

# %% [markdown]
# #### Select all free orders.

# %%
# your code here
orders[(orders['UnitPrice'] == 0)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here
orders[(orders['Description'].apply(lambda x : x.startswith('lunch bag')))]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here
orders[(orders['Description'].apply(lambda x : x.startswith('lunch bag'))) & (orders['year'] == 2011)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here
amountspent_spain = orders[(orders['Country'] == 'Spain')]['amount_spent']
sns.distplot(amountspent_spain, bins=10)

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here
orders[(orders['month'] == 8)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here
orders[(orders['month'] == 8)].groupby(by='Country').sum()
# Out:
#                  Unnamed: 0    InvoiceNo      year   month    day    hour  \
# Country
# Australia          32576265     60302348    215177     856    438     916
# Austria            26212020     49543386    176968     704    208     880
# Belgium            58480484    109287235    390134    1552    739    2448
# Canada              1564810      2822140     10055      40     20      55
# Channel Islands    43046490     78948531    281540    1120    287    1570
# Denmark             4739080      9005648     32176     128     48     160
# EIRE              177784872    333975511   1192523    4744   2423    8087
# Finland            18366395     34362298    122671     488    264     618
# France            174350986    320802556   1144259    4552   2200    6641
# Germany           241648824    448042055   1598745    6360   2299    9296
# Iceland             6305893     12364704     44242     176     44     176
# ...

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here
orders.groupby(by='Country')[['amount_spent']].mean()
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here
orders[['Description', 'UnitPrice']].max()
# Out:
# Description    zinc wire sweetheart letter tray
# UnitPrice                               8142.75
# dtype: object

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here
orders.groupby(by='year')[['amount_spent']].mean()
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
