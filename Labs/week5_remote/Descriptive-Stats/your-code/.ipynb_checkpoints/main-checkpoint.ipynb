# %% [markdown]
# ## Understanding Descriptive Statistics
#
# Import the necessary libraries here:

# %%
# Libraries
import pandas as pd
import matplotlib.pyplot as plt
import random
import seaborn as sns
# Out:
# C:\Users\pedro\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Challenge 1
# ## Define a function that simulates rolling a dice 10 times. Save the information in a dataframe.
# **Hint**: you can use the *choices* function from module *random* to help you with the simulation.

# %%
def rolling_dice():
    return pd.DataFrame(random.choices(np.arange(1,7), k=10), columns=['values'])

# %% [markdown]
# ## Plot the results sorted by value.

# %%
# your code here
rolling_dice().sort_values(by='values').plot(kind='hist')

# %% [markdown]
# #### 3.- Calculate the frequency distribution and plot it. What is the relation between this plot and the plot above? Describe it with words.

# %%
# your code here
rolling_dice()['values'].value_counts().plot(kind='bar')

# %% [markdown]
# # Challenge 2
# Now, using the dice results obtained in *challenge 1*, your are going to define some functions that will help you calculate the mean of your data in two different ways, the median and the four quartiles.
#
# ## Define a function that computes the mean by summing all the observations and dividing by the total number of observations. You are not allowed to use any methods or functions that directly calculate the mean value.

# %%
# your code here
dice = rolling_dice()
def calc_mean(lst):
    return sum(lst)/len(lst)
calc_mean(dice['values'])
# Out:
# 3.1

# %% [markdown]
# ## 2.- First, calculate the frequency distribution. Then, calculate the mean using the values of the frequency distribution you've just computed. You are not allowed to use any methods or functions that directly calculate the mean value.

# %%
# your code here
def freq_calc_mean(lst):
    freq = [[item,lst.count(item)] for item in set(lst)]
    freq_item = [item[0]*item[1] for item in freq]
    return sum(freq_item)/len(lst)
freq_calc_mean(list(dice['values']))
# Out:
# 3.1

# %% [markdown]
# #### 3.- Define a function to calculate the median. You are not allowed to use any methods or functions that directly calculate the median value.
# **Hint**: you might need to define two computation cases depending on the number of observations used to calculate the median.

# %%
# your code here
def median(lst):
    lst = sorted(lst)
    if len(lst)%2 == 0:
        x = int((len(lst)/2))
        return (lst[x] + lst[x-1])/2
    else:
        return lst[int((len(lst)/2))]
median(list(dice['values']))
# Out:
# 3.0

# %% [markdown]
# #### 4.- Define a function to calculate the four quartiles. You can use the function you defined above to compute the median but you are not allowed to use any methods or functions that directly calculate the quartiles.

# %%
# your code here
def cal_quartiles(lst):
    med = median(lst)
    lst = sorted(lst)
    mid = int(len(lst)/2)
    if len(lst)%2 == 0:
        q1 = median(lst[0:mid])
        q3 = median(lst[mid:len(lst)])
    else:
        q1 = median(lst[0:mid])
        q3 = median(lst[mid+1:len(lst)])
    return f'25%: {q1}, 50%: {med}, 75%: {q3}'
cal_quartiles(list(dice['values']))
# Out:
# '25%: 2, 50%: 3.0, 75%: 4'

# %% [markdown]
# ## Challenge 3
# Read the csv `roll_the_dice_hundred.csv` from the `data` folder.
# #### 1.- Sort the values and plot them. What do you see?

# %%
# your code here
df = pd.read_csv('../data/roll_the_dice_hundred.csv')
df['value'].plot(kind='hist')

# %%
"""
your comments here
The frequency varies between 12 and 23 times
"""
# Out:
# '\nyour comments here\nThe frequency varies between 12 and 23 times\n'

# %% [markdown]
# #### 2.- Using the functions you defined in *challenge 2*, calculate the mean value of the hundred dice rolls.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'roll', 'value'], dtype='object')

# %%
# your code here
calc_mean(df['value'])
# Out:
# 3.74

# %% [markdown]
# #### 3.- Now, calculate the frequency distribution.

# %%
# your code here
df['value'].value_counts()
# Out:
# 6    23
# 4    22
# 2    17
# 3    14
# 5    12
# 1    12
# Name: value, dtype: int64

# %% [markdown]
# #### 4.- Plot the histogram. What do you see (shape, values...) ? How can you connect the mean value to the histogram?

# %%
# your code here
df['value'].plot.hist()

# %%
"""
your comments here
the mean is next from the center of plo
"""

# %% [markdown]
# #### 5.- Read the `roll_the_dice_thousand.csv` from the `data` folder. Plot the frequency distribution as you did before. Has anything changed? Why do you think it changed?

# %%
# your code here
df = pd.read_csv('../data/roll_the_dice_thousand.csv')
df['value'].plot.hist()

# %%
"""
your comments here
The difference between frequencies has been reduced
"""

# %% [markdown]
# ## Challenge 4
# In the `data` folder of this repository you will find three different files with the prefix `ages_population`. These files contain information about a poll answered by a thousand people regarding their age. Each file corresponds to the poll answers in different neighbourhoods of Barcelona.
#
# #### 1.- Read the file `ages_population.csv`. Calculate the frequency distribution and plot it as we did during the lesson. Try to guess the range in which the mean and the standard deviation will be by looking at the plot.

# %%
# your code here
df = pd.read_csv('../data/ages_population.csv')
df.plot.hist()

# %% [markdown]
# #### 2.- Calculate the exact mean and standard deviation and compare them with your guesses. Do they fall inside the ranges you guessed?

# %%
df.columns
# Out:
# Index(['observation'], dtype='object')

# %%
calc_mean(df['observation'])
# Out:
# 36.56

# %%
# your code here
df.std(axis=0)
# Out:
# observation    12.8165
# dtype: float64

# %%
"""
your comments here
Whe can see the center of plot is next from the mean, and them with we create a range plus or minus mean std, the most of observations are in there
"""

# %% [markdown]
# #### 3.- Now read the file `ages_population2.csv` . Calculate the frequency distribution and plot it.

# %%
# your code here
df = pd.read_csv('../data/ages_population2.csv')
df.plot.hist()

# %% [markdown]
# ####  4.- What do you see? Is there any difference with the frequency distribution in step 1?

# %%
"""
your comments here
the format of the histogram are similar from the above, but we have more concentration on the left side
"""

# %% [markdown]
# #### 5.- Calculate the mean and standard deviation. Compare the results with the mean and standard deviation in step 2. What do you think?

# %%
# your code here
df.std(axis=0)
# Out:
# observation    2.969814
# dtype: float64

# %%
calc_mean(df['observation'])
# Out:
# 27.155

# %%
"""
your comments here
the mean and std are different, but the plot is similar
"""

# %% [markdown]
# ## Challenge 5
# Now is the turn of `ages_population3.csv`.
#
# #### 1.- Read the file `ages_population3.csv`. Calculate the frequency distribution and plot it.

# %%
# your code here
df = pd.read_csv('../data/ages_population3.csv')
df.plot.hist()

# %% [markdown]
# #### 2.- Calculate the mean and standard deviation. Compare the results with the plot in step 1. What is happening?

# %%
# your code here
calc_mean(df['observation'])
# Out:
# 41.989

# %%
df.std(axis=0)
# Out:
# observation    16.144706
# dtype: float64

# %%
"""
your comments here
in this plot, the mean increases from other, and the std are next from step 1
"""

# %% [markdown]
# #### 3.- Calculate the four quartiles. Use the results to explain your reasoning for question in step 2. How much of a difference is there between the median and the mean?

# %%
# your code here
cal_quartiles(df['observation'])
# Out:
# '25%: 30.0, 50%: 40.0, 75%: 53.0'

# %%
"""
your comments here
We can see from the quartiles that more than 50% of people are over 40
"""

# %% [markdown]
# #### 4.- Calculate other percentiles that might be useful to give more arguments to your reasoning.

# %%
# your code here
df.quantile([.1,.2,.3,.4,.5,.6,.7,.8,.9,1])
# Out:
#      observation
# 0.1         22.0
# 0.2         28.0
# 0.3         32.0
# 0.4         36.0
# 0.5         40.0
# 0.6         45.0
# 0.7         50.0
# 0.8         57.0
# 0.9         67.0
# 1.0         77.0

# %%
"""
your comments here
We can see from the quartiles that more than 30% of people are over 50
"""

# %% [markdown]
# ## Bonus challenge
# Compare the information about the three neighbourhoods. Prepare a report about the three of them. Remember to find out which are their similarities and their differences backing your arguments in basic statistics.

# %%
# your code here
df1 = pd.read_csv('../data/ages_population.csv')
df2 = pd.read_csv('../data/ages_population2.csv')
df3 = pd.read_csv('../data/ages_population3.csv')
axes[0]=df.plot(kind='hist')
axes[1]=df1.plot(kind='hist')
axes[2]=df2.plot(kind='hist')
plt.show()

# %%
"""
your comments here
the distribution in the three neighborhoods is close but we see that in one neighborhood there is a tendency to have older people, in the other younger and in the other more middle age
"""
